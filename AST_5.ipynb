# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Understanding the Data

# %%
df=pd.read_csv('/content/Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.corr()
# Out:
# <ipython-input-6-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %% [markdown]
# # Data Preprocessing
# ## Data Visualisation

# %%
sns.displot(df.Age)

# %%
sns.lineplot(data=df,x='Age',y='Annual Income (k$)')
# Out:
# <Axes: xlabel='Age', ylabel='Annual Income (k$)'>

# %%
sns.pairplot(df)

# %% [markdown]
# ## Oulier Detection and Removal

# %%
sns.boxplot(df.Age)
# Out:
# <Axes: >

# %%
sns.boxplot(df['Annual Income (k$)'])
# Out:
# <Axes: >

# %%
Q1 = df['Annual Income (k$)'].quantile(0.25)
Q3 = df['Annual Income (k$)'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
fa=df['Annual Income (k$)'].median()
df['Annual Income (k$)']=np.where(df['Annual Income (k$)']>upper_bound,fa,df['Annual Income (k$)'])
sns.boxplot(df['Annual Income (k$)'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Spending Score (1-100)'])
# Out:
# <Axes: >

# %% [markdown]
# ## Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df.Gender=le.fit_transform(df.Gender)
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                15.0                      39
# 1           2       1   21                15.0                      81
# 2           3       0   20                16.0                       6
# 3           4       0   23                16.0                      77
# 4           5       0   31                17.0                      40

# %% [markdown]
# # K-means Clustering

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1       1   19                15.0                      39
# 1           2       1   21                15.0                      81
# 2           3       0   20                16.0                       6
# 3           4       0   23                16.0                      77
# 4           5       0   31                17.0                      40

# %%
# Removing the first column(CustomerID)
df_new = df.iloc[ : , 1: ]

# %%
df_new
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0         1   19                15.0                      39
# 1         1   21                15.0                      81
# 2         0   20                16.0                       6
# 3         0   23                16.0                      77
# 4         0   31                17.0                      40
# ..      ...  ...                 ...                     ...
# 195       0   35               120.0                      79
# 196       0   45               126.0                      28
# 197       1   32               126.0                      74
# 198       1   32                61.5                      18
# 199       1   30                61.5                      83
#
# [200 rows x 4 columns]

# %%
df_new['Spending Score (1-100)'].value_counts()
# Out:
# 42    8
# 55    7
# 46    6
# 73    6
# 35    5
#      ..
# 31    1
# 44    1
# 53    1
# 65    1
# 18    1
# Name: Spending Score (1-100), Length: 84, dtype: int64

# %%
from sklearn.cluster import KMeans
error=[]
for i in range(1,11):
  kmeans = KMeans(n_clusters=i,random_state=0)
  kmeans.fit(df_new[['Annual Income (k$)','Spending Score (1-100)']])
  error.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
error
# Out:
# [258182.89500000005,
#  171461.67386954778,
#  102283.01391906125,
#  69614.42989643844,
#  40494.033637799395,
#  34728.61250605758,
#  29079.527525982565,
#  23885.154432307656,
#  20710.67806616173,
#  18654.24865249818]

# %% [markdown]
# ## Elbow Method

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1,11), error, marker='o', linestyle='-')
plt.xlabel('Number of Clusters')
plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
plt.title('Elbow Method')
plt.grid(True)
plt.show()

# %%
elbow_point = None
wcss=error
k_values = range(1,11)
for i in range(1, len(wcss)):
    if wcss[i - 1] - wcss[i] < 0.1 * wcss[0]:
        elbow_point = k_values[i - 1]
        break

print(f"The estimated elbow point is at {elbow_point} clusters.")
# Out:
# The estimated elbow point is at 5 clusters.

# %% [markdown]
# ## Predicting

# %%
km_model = KMeans(n_clusters=5,init = 'k-means++',random_state=0)
km_model.fit(df_new)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=0)

# %%
pred = km_model.predict(df_new)
pred
# Out:
# array([4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0,
#        4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 0, 4, 2,
#        4, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 3, 1, 2, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 2, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1, 3, 1,
#        3, 1], dtype=int32)

# %%
df_new.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0       1   19                15.0                      39
# 1       1   21                15.0                      81
# 2       0   20                16.0                       6
# 3       0   23                16.0                      77
# 4       0   31                17.0                      40

# %%
km_model.predict([[1,8,90,9]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([3], dtype=int32)

# %%
km_model.predict([[0,20,55,33]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([2], dtype=int32)

# %%
km_model.predict([[1,45,6,45]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([4], dtype=int32)

# %%
chosen_k = 5
kmeans = KMeans(n_clusters=chosen_k, init='k-means++', random_state=42,n_init=10)
df_new['KMeans_Cluster'] = kmeans.fit_predict(df_new[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df_new, x='Annual Income (k$)', y='Spending Score (1-100)', hue='KMeans_Cluster', palette='Dark2')
plt.title('K-Means Clustering')
plt.show()
